# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
#create a string that includes opeing and closing quotaion marks

# %%
mystring = '"we\'re moving toL.A.!"'
print(mystring)
# Out:
# "we're moving toL.A.!"

# %%
doc = nlp(mystring)

# %%
for t in mystring:
    print(t)
# Out:
# "
# w
# e
# '
# r
# e
#
# m
# o
# v
# i
# n
# g
#
# t
# o
# L
# .
# A
# .
# !
# "

# %%
doc2 = nlp(u"we're here to help! send snail-mail , email support@website.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
    print(t)
# Out:
# we
# 're
# here
# to
# help
# !
# send
# snail
# -
# mail
# ,
# email
# support@website.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc3  = nlp(u"A 5km NYC cab ride costs $10.30")
for t in doc3:
    print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %%
doc4 = nlp(u"Let's visit St.Louis in the U.S. next year.")
for t in doc4:
    print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc)
# Out:
# 7

# %%
len(doc.vocab)
# Out:
# 794

# %% [markdown]
# token can be retrievd by index positon and slice

# %%
doc5 = nlp(u"it is better to give than to receive.")

doc5[3]
# Out:
# to

# %%
doc5[3:7]
# Out:
# to give than to

# %%
doc5[-4:]
# Out:
# than to receive.

# %% [markdown]
# token cannot be reassigned

# %%
doc6 = nlp("my dinner was horrible.")
doc7 = nlp("your dinner was delicious.")

# %%
#doc6[3] = doc7[3]

# %%
doc6[3] = "paul"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4247694062.py in <cell line: 0>()
# ----> 1 doc6[3] = "paul"
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
doc8 = nlp("Apple to build a hong kong factory for $6 million")

for token in doc8:
  print(token.text, end=' | ')

print('\n-----')\

for ent in doc8.ents:
  print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
# Out:
# Apple | to | build | a | hong | kong | factory | for | $ | 6 | million |
# -----
# Apple - ORG - Companies, agencies, institutions, etc.
# hong kong - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %% [markdown]
# noun chuncks

# %%
doc9 = nlp("Autonomous cars shift insurance liability toward manufacturers.")

for chunk in doc9.noun_chunks:
  print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp("Red cars do not carry higher insurance rates.")

for chunk in doc10.noun_chunks:
  print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %%
doc11 = nlp("he was a one-eyed, one-horned, flying, purple people-eater.")

for chunk in doc11.noun_chunks:
  print(chunk.text)
# Out:
# he
# a one-eyed, one-horned, flying, purple people-eater

# %% [markdown]
# built in visualizes

# %%
from spacy import displacy

# %%
doc = nlp(u'apple is going to build a U.K> factory for $6 million.')
displacy.render(doc , style='dep', jupyter=True, options={'distance':80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3f08b3e20fa4d8cbe623b2d25b2632d-0" class="displacy" width="1090" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
# ...

# %%
doc = nlp(u'open the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc , style='ent', jupyter=True, options={'distance':80})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">open
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
# ...

# %%
doc = nlp(u'Over the last quater Apple sold nearly 20thousand iPods for a profit of $6 million.')
displacy.render(doc,style='ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quater
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20thousand
# ...
